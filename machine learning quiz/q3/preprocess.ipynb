# %%
import pandas as pd

def load_data(path, independent_var, response_var):
    
    data = pd.read_csv("C://Users/302-24/Desktop/machine learning/(250320) 머신러닝 분류 실습/q3/data/iris.csv", header=0)
    
    data = data[(data['class_num'] == 1) | (data['class_num'] == 2)]
    
    x_mat = data.loc[:, independent_var].values.reshape(-1, 2)
    y_vec = data.loc[:, response_var].values.reshape(-1, )
    
    # 전체 데이터를 훈련용과 검증용으로 나눕니다.
    x_train = x_mat[10:]
    y_train = y_vec[10:]
    x_val = x_mat[0:10]
    y_val = y_vec[0:10]
    
    return x_train, y_train, x_val, y_val

# %%
data = pd.read_csv("C://Users/302-24/Desktop/machine learning/(250320) 머신러닝 분류 실습/q3/data/iris.csv", header=0)

# %%
data
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  \
# 0             0           6.9          3.1           5.1          2.3
# 1             1           4.9          3.1           1.5          0.1
# 2             2           6.2          2.9           4.3          1.3
# 3             3           6.2          2.8           4.8          1.8
# 4             4           4.6          3.2           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         145           6.4          2.7           5.3          1.9
# 146         146           6.7          3.1           5.6          2.4
# 147         147           7.9          3.8           6.4          2.0
# 148         148           5.7          2.5           5.0          2.0
# 149         149           5.7          3.0           4.2          1.2
#
#                class  class_num
# 0     Iris-virginica          2
# 1        Iris-setosa          0
# 2    Iris-versicolor          1
# 3     Iris-virginica          2
# 4        Iris-setosa          0
# ..               ...        ...
# 145   Iris-virginica          2
# 146   Iris-virginica          2
# 147   Iris-virginica          2
# 148   Iris-virginica          2
# 149  Iris-versicolor          1
#
# [150 rows x 7 columns]
